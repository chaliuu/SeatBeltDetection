# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC as lsvc
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from roboflow import Roboflow
import json
import PIL

# %%
#Citation: the code below reference code from APS360 Lab 2

# %%
#Citation: this code is given by Roboflow to install dataset
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gMTVjr2tVu8feJmkrnPs")
project = rf.workspace("aps360-project-6tmc3").project("aps360_-2")
dataset = project.version(1).download("coco")
# Out:
# Access is denied.
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in APS360_(2)-1 to coco: 100% [68721173 / 68721173] bytes
# Extracting Dataset Version Zip to APS360_(2)-1 in coco:: 100%|████████████████████| 1445/1445 [00:10<00:00, 131.72it/s]

# %%
#data preprocessing
def open_coco_file(coco_annots_file_path):
    #takes in the file path to a coco annotations and  
    #returns a dictionary of image id and a tuple of image file path and category
    flat_img_list = []
    labels_list = []
    with open(os.path.join(coco_annots_file_path,"_annotations.coco.json"), 'r') as f:
            file = json.load(f)
    
    for id in range(len(file['images'])):
        img_path = file['images'][id]['file_name']
        img_label = file['annotations'][id]['category_id']
        
        img_arr = np.array(PIL.Image.open(os.path.join(coco_annots_file_path,img_path)))
        flat_img_list.append(resize(img_arr,(150,150,3)).flatten())
        if img_label == 1:
            labels_list.append('seatbelt')
        elif img_label == 2:
            labels_list.append('no-seatbelt')
    df=pd.DataFrame(flat_img_list) 
    df['Labels']=labels_list
    return df

# %%
train_path = "./APS360_(2)-1/train"
test_path = "./APS360_(2)-1/test"
df_train = open_coco_file(train_path)
df_test = open_coco_file(test_path)

# %%
df_test.shape
# Out:
# (272, 67501)

# %%
df_test
# Out:
#             0         1         2         3         4         5         6
# 0    0.576540  0.643124  0.611792  0.575963  0.636654  0.607627  0.596163  \
# 1    0.156400  0.152478  0.132871  0.157802  0.153880  0.134273  0.165358
# 2    0.292824  0.312432  0.284981  0.293916  0.313524  0.286073  0.296810
# 3    0.385893  0.403886  0.402607  0.389298  0.408319  0.398364  0.396795
# 4    0.514300  0.611942  0.594664  0.532139  0.619826  0.606346  0.470992
# ..        ...       ...       ...       ...       ...       ...       ...
# 267  0.374501  0.378504  0.347091  0.375077  0.379079  0.347666  0.373621
# 268  0.860163  0.835314  0.517246  0.831293  0.798575  0.491715  0.810127
# 269  0.100337  0.165901  0.072806  0.232992  0.332480  0.193800  0.348366
# 270  0.505886  0.533337  0.564710  0.507168  0.534619  0.565992  0.513315
# 271  0.469815  0.446286  0.352168  0.490437  0.466907  0.372790  0.494537
#
#             7         8         9  ...     67491     67492     67493
# 0    0.645937  0.619295  0.594584  ...  0.728365  0.744593  0.778254  \
# 1    0.161437  0.141829  0.164263  ...  0.123003  0.138684  0.134763
# 2    0.316418  0.288967  0.292915  ...  0.771316  0.712407  0.636881
# 3    0.417714  0.395942  0.378800  ...  0.109913  0.125545  0.137322
0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#         67493     67494     67495     67496         67497         67498
# 0    0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000e+00  \
# 1    0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000e+00
# 2    0.120402  0.000551  0.000472  0.008973  2.499575e-07  2.227862e-07
# 3    0.117649  0.117647  0.117647  0.117647  1.176471e-01  1.176471e-01
# 4    0.168627  0.168627  0.168627  0.168627  1.686275e-01  1.686275e-01
# ..        ...       ...       ...       ...           ...           ...
# 897  0.176471  0.176471  0.176471  0.176471  1.764706e-01  1.764706e-01
# 898  0.180816  0.128569  0.128569  0.128569  1.176598e-01  1.176598e-01
# 899  0.168624  0.168627  0.168627  0.168627  1.686275e-01  1.686275e-01
# 900  0.188235  0.188235  0.188235  0.188235  1.882353e-01  1.882353e-01
# 901  0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000e+00
#
#         67499       Labels
# 0    0.000000     seatbelt
# 1    0.000000     seatbelt
# 2    0.006353  no-seatbelt
# 3    0.117647     seatbelt
# 4    0.168627  no-seatbelt
# ..        ...          ...
# 897  0.176471  no-seatbelt
# 898  0.117660  no-seatbelt
# 899  0.168627     seatbelt
# 900  0.188235  no-seatbelt
# 901  0.000000     seatbelt
#
# [902 rows x 67501 columns]

# %%
#input data 
x_train=df_train.iloc[:,:-1] 
x_test=df_test.iloc[:,:-1]
#output data
y_train=df_train.iloc[:,-1]
y_test=df_test.iloc[:,-1]
y_train[:4]
# Out:
# 0       seatbelt
# 1       seatbelt
# 2    no-seatbelt
# 3       seatbelt
# Name: Labels, dtype: object

# %%
from sklearn import svm
# Defining the parameters grid for GridSearchCV
param_grid={'C':[0.1,1,10,100],
            'gamma':[0.0001,0.001,0.1,1]}
  
# Creating a support vector classifier
LSVC=svm.lsvc(kernel="linear",probability=True)
# Creating a model using GridSearchCV with the parameters grid
model=GridSearchCV(LSVC,param_grid)

# %%
# Training the model using the training data
model.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(kernel='linear', probability=True),
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [0.0001, 0.001, 0.1, 1]})

# %%
# Testing the model using the testing data
y_pred = model.predict(x_test)

# %%
# Calculating the accuracy of the model
accuracy = accuracy_score(y_pred, y_test)
      
# Print the accuracy of the model
print(f"The model is {accuracy*100}% accurate")
# Out:
# The model is 44.48529411764706% accurate

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['seatbelt', 'no-seatbelt']))
# Out:
#               precision    recall  f1-score   support
#
#     seatbelt       0.92      0.43      0.59       250
#  no-seatbelt       0.08      0.59      0.15        22
#
#     accuracy                           0.44       272
#    macro avg       0.50      0.51      0.37       272
# weighted avg       0.86      0.44      0.55       272
